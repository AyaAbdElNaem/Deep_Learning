# %% [markdown]
# <a href="https://colab.research.google.com/github/AyaAbdElNaem/Deep_Learning/blob/main/CN_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/tensorflow/docs
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-czbb7_ly
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/docs /tmp/pip-req-build-czbb7_ly
#   Resolved https://github.com/tensorflow/docs to commit 0054afff57cd4a4ea5389088a89942603461ee6f
#   Preparing metadata (setup.py) ... done
# Collecting astor (from tensorflow-docs==2026.5.12.61975)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from tensorflow-docs==2026.5.12.61975) (1.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-docs==2026.5.12.61975) (3.1.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from tensorflow-docs==2026.5.12.61975) (5.10.4)
# Requirement already satisfied: protobuf>=3.12 in /usr/local/lib/python3.12/dist-packages (from tensorflow-docs==2026.5.12.61975) (5.29.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from tensorflow-docs==2026.5.12.61975) (6.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->tensorflow-docs==2026.5.12.61975) (3.0.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->tensorflow-docs==2026.5.12.61975) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->tensorflow-docs==2026.5.12.61975) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->tensorflow-docs==2026.5.12.61975) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->tensorflow-docs==2026.5.12.61975) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2026.5.12.61975) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2026.5.12.61975) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2026.5.12.61975) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->tensorflow-docs==2026.5.12.61975) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->tensorflow-docs==2026.5.12.61975) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->tensorflow-docs==2026.5.12.61975) (4.15.0)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-2026.5.12.61975-py3-none-any.whl size=186932 sha256=ceddd43ee5165e2e575acfc22542e21ec92970d203873f5494de6acf6c8b38da
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qj6jdfm1/wheels/3e/88/34/48d2789bc9d37b33ddce06bccc454fae0285e5396d0a5be9d9
# Successfully built tensorflow-docs
# Installing collected packages: astor, tensorflow-docs
# Successfully installed astor-0.8.1 tensorflow-docs-2026.5.12.61975

# %%
# general libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# tensorflow libraries
import tensorflow as tf
from tensorflow import keras
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
from tensorflow.keras import layers, models

# %%
((trainX, trainY), (testX, testY)) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print('Dimensions of the training dataset: ', trainX.shape)
print('Dimensions of the test dataset: ', testX.shape)
print('Dimensions of the training labels: ', trainY.shape)
print('Dimensions of the test labels: ', testY.shape)
# Out:
# Dimensions of the training dataset:  (60000, 28, 28)
# Dimensions of the test dataset:  (10000, 28, 28)
# Dimensions of the training labels:  (60000,)
# Dimensions of the test labels:  (10000,)

# %%
labels_train = np.zeros((60000, 10))
labels_train[np.arange(60000), trainY] = 1

data_train = trainX.reshape(60000, 28, 28, 1)

labels_test = np.zeros((10000, 10))
labels_test[np.arange(10000), testY] = 1

data_test = testX.reshape(10000, 28, 28, 1)

# %%
print('Dimensions of the training dataset: ', data_train.shape)
print('Dimensions of the test dataset: ', data_test.shape)
print('Dimensions of the training labels: ', labels_train.shape)
print('Dimensions of the test labels: ', labels_test.shape)
# Out:
# Dimensions of the training dataset:  (60000, 28, 28, 1)
# Dimensions of the test dataset:  (10000, 28, 28, 1)
# Dimensions of the training labels:  (60000, 10)
# Dimensions of the test labels:  (10000, 10)

# %%
data_train_norm = np.array(data_train/255.0)
data_test_norm = np.array(data_test/255.0)

# %%
def build_model():
  # create model
  model = models.Sequential()
  model.add(layers.Conv2D(16, (5, 5), strides = (1, 1), activation = 'relu', input_shape = (28, 28, 1)))
  model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
  model.add(layers.Conv2D(32, (5, 5), strides = (1, 1), activation = 'relu'))
  model.add(layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation = 'relu'))
  model.add(layers.Dense(10, activation = 'softmax'))
  # compile model
  model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['categorical_accuracy'])
  return model

# %%
Digits_model = build_model()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
Digits_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 16)     │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 12, 12, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 32)       │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,202 (313.29 KB)
#  Trainable params: 80,202 (313.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Model Training

# %%
EPOCHS = 10

history = Digits_model.fit(
  data_train_norm, labels_train,
  epochs = EPOCHS, verbose = 1,
  batch_size = 100)
# Out:
# Epoch 1/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - categorical_accuracy: 0.9390 - loss: 0.2135
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 33s 56ms/step - categorical_accuracy: 0.9825 - loss: 0.0584
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - categorical_accuracy: 0.9882 - loss: 0.0408
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - categorical_accuracy: 0.9898 - loss: 0.0326
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 33s 56ms/step - categorical_accuracy: 0.9925 - loss: 0.0243
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - categorical_accuracy: 0.9931 - loss: 0.0215
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - categorical_accuracy: 0.9944 - loss: 0.0176
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - categorical_accuracy: 0.9954 - loss: 0.0139
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 33s 54ms/step - categorical_accuracy: 0.9960 - loss: 0.0123
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 32s 53ms/step - categorical_accuracy: 0.9960 - loss: 0.0115

# %%
test_loss, test_accuracy = Digits_model.evaluate(data_test_norm, labels_test, verbose = 0)
print('The accuracy on the test set is equal to: ', int(test_accuracy*100), '%.')
# Out:
# The accuracy on the test set is equal to:  99 %.
